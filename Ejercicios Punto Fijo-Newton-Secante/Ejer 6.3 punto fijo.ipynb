# %%
from math import *
import numpy as np
import matplotlib.pyplot as plt

def error(X_nuevo, X_anterior):
    return abs((X_nuevo - X_anterior) / X_nuevo) * 100

def g(x):
    return sqrt(2.5 + 1.8*x)

tolerancia = 0.05
iter = 10
x_0 = 5
i = 0    
list_error = [100]    
list_x = []
list_i = []
    
while(list_error[-1] >= tolerancia):
    x = g(x_0)
        
    if(error(x , x_0) < tolerancia):
        print(f"En la iteracion {i + 1} se encuentra el punto fijo con un error de {error(x, x_0)}%")

    if i >= 1:
        list_error.append(error(x, x_0))
            
    list_x.append(x)
    list_i.append(i + 1)
    print(f"En la iteracion {i + 1} x = {x} con un error de {error(x, x_0)}%")    
    x_0 = x
    i += 1
        

plt.figure(figsize=(10, 6))

plt.subplot(2, 1, 1)
plt.plot(list_i, list_x, marker='o', color='b')
plt.title('Convergencia de xn')
plt.xlabel('Iteración')
plt.ylabel('xn')

plt.subplot(2, 1, 2)
plt.plot(list_i, list_error, marker='o', color='r')
plt.title('Error Relativo')
plt.xlabel('Iteración')
plt.ylabel('Error (%)')

plt.tight_layout()
plt.show()
# Out:
# En la iteracion 1 x = 3.391164991562634 con un error de 47.441956154897134%
# En la iteracion 2 x = 2.9332741066618273 con un error de 15.61023171550453%
# En la iteracion 3 x = 2.789246025719368 con un error de 5.163692252830709%
# En la iteracion 4 x = 2.7423790486172517 con un error de 1.7089897593021361%
# En la iteracion 5 x = 2.726954764478328 con un error de 0.565623029022798%
# En la iteracion 6 x = 2.7218593968206717 con un error de 0.1872017218673355%
# En la iteracion 7 x = 2.7201740595552355 con un error de 0.061956964096324944%
# En la iteracion 8 se encuentra el punto fijo con un error de 0.020505459653667575%
# En la iteracion 8 x = 2.7196163897137082 con un error de 0.020505459653667575%
