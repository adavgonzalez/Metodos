# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return -x**2 + 1.8*x + 2.5

def m(x): #derivada
    return -2*x + 1.8

def error(X_nuevo, X_anterior):
    return np.abs((X_nuevo - X_anterior) / X_nuevo)*100

a = 5 #valor inicial
i = 0
iter = 3
list_i = []
list_xn = []
list_error = [100]
tolerancia = 0.05

while list_error[-1] >= tolerancia:
    xn = a - (f(a) / m(a))
    list_xn.append(xn)
    
    list_i.append(i)
    if i >= 1:
        list_error.append(error(list_xn[-1], list_xn[-2]))
    print(f"En la iteracion {i} xn es igual a: {xn}")
    print(f"En la iteracion {i} el error es igual a: {list_error[-1]}%\n")
    print("------------------------------------------------------\n")
    a = xn  
    i += 1

print(f"la raiz es igual a: {xn}")

plt.figure(figsize=(12, 8))

plt.subplot(2, 1, 1)
plt.plot(list_i, list_xn, color='b')
plt.title('Convergencia de xn')
plt.xlabel('Iteración')
plt.ylabel('xn')
plt.grid()

plt.subplot(2, 1, 2)
plt.plot(list_i, list_error, color='r')
plt.title('Error Relativo')
plt.xlabel('Iteración')
plt.ylabel('Error (%)')
plt.grid()

plt.tight_layout()
plt.show()
# Out:
# En la iteracion 0 xn es igual a: 3.3536585365853657
# En la iteracion 0 el error es igual a: 100%
#
# ------------------------------------------------------
#
# En la iteracion 1 xn es igual a: 2.801332250400039
# En la iteracion 1 el error es igual a: 19.71655758100286%
#
# ------------------------------------------------------
#
# En la iteracion 2 xn es igual a: 2.721108416205071
# En la iteracion 2 el error es igual a: 2.948204258132801%
#
# ------------------------------------------------------
#
# En la iteracion 3 xn es igual a: 2.7193413979661587
# En la iteracion 3 el error es igual a: 0.06497963956396999%
#
# ------------------------------------------------------
#
# En la iteracion 4 xn es igual a: 2.7193405398662276
# En la iteracion 4 el error es igual a: 3.155544215707621e-05%
#
# ------------------------------------------------------
#
# la raiz es igual a: 2.7193405398662276
