# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return x**3 + 2 * x**2 + 10 * x - 20

def m(x):
    return 3 * x ** 2 + 4 * x + 10

def error(X_nuevo, X_anterior):
    return np.abs((X_nuevo - X_anterior) / X_nuevo)

a = 10
i = 0
iter = 10
Error = 100
list_i = []
list_xn = []
list_error = []
tolerancia = 0.01

while iter >= i:
    xn = a - (f(a)/ m(a))
    list_xn.append(xn)
    if xn < a:
        a = xn
    if i >= 1:
        Error = error(list_xn[-1], list_xn[-2])
    list_i.append(i)
    list_error.append(Error)
    print(f"En la iteracion {i} xn es igual a: {xn}")
    print(f"En la iteracion {i} el error es igual a: {Error}")
    print("")
    i += 1
print(f"la raiz es igual a: {xn}")

plt.figure(figsize=(12, 8))

plt.subplot(2, 1, 1)
plt.plot(list_i, list_xn, color='b')
plt.title('Convergencia de xn')
plt.xlabel('Iteración')
plt.ylabel('xn')
plt.grid()

plt.subplot(2, 1, 2)
plt.plot(list_i, list_error, color='r')
plt.title('Error Relativo')
plt.xlabel('Iteración')
plt.ylabel('Error (%)')
plt.grid()

plt.tight_layout()
plt.show()
# Out:
# En la iteracion 0 xn es igual a: 6.342857142857143
# En la iteracion 0 el error es igual a: 100
#
# En la iteracion 1 xn es igual a: 3.913918375459734
# En la iteracion 1 el error es igual a: 2.428938767397409
#
# En la iteracion 2 xn es igual a: 2.381589333217148
# En la iteracion 2 el error es igual a: 1.5323290422425861
#
# En la iteracion 3 xn es igual a: 1.5970695396713386
# En la iteracion 3 el error es igual a: 0.7845197935458095
#
# En la iteracion 4 xn es igual a: 1.383032261056769
# En la iteracion 4 el error es igual a: 0.21403727861456967
#
# En la iteracion 5 xn es igual a: 1.3688664632732384
# En la iteracion 5 el error es igual a: 0.014165797783530554
#
# En la iteracion 6 xn es igual a: 1.368808108807063
# En la iteracion 6 el error es igual a: 5.835446617541429e-05
#
# En la iteracion 7 xn es igual a: 1.3688081078213725
# En la iteracion 7 el error es igual a: 9.856904181759774e-10
#
# En la iteracion 8 xn es igual a: 1.3688081078213725
# En la iteracion 8 el error es igual a: 0.0
#
# En la iteracion 9 xn es igual a: 1.3688081078213725
# En la iteracion 9 el error es igual a: 0.0
#
# En la iteracion 10 xn es igual a: 1.3688081078213725
# En la iteracion 10 el error es igual a: 0.0
#
# la raiz es igual a: 1.3688081078213725
