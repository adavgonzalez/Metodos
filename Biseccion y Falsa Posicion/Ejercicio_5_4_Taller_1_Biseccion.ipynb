# %% [markdown]
# Ejercicio 5.4 por metodo de biseccion

# %%
#Ejercicio 5.4 por metodo de biseccion

import numpy as np
import matplotlib.pyplot as plt

def funcion(x):
    return -13 - 20 * x + 19 * x ** 2 - 3 * x ** 3

def error(X_nuevo, X_anterior):
    return abs((X_nuevo - X_anterior) / X_nuevo) * 100

a = -1
b = 0

tolerancia = 1E-2

i = 0
list_xn = []
list_i = []
list_error = []
Error = 100

fa = funcion(a)
fb = funcion(b)

while Error >= tolerancia:

    if fa * fb == 0:

        if fa == 0:
            print(f"La raíz es {a}")

        elif fb == 0:
            print(f"La raíz es {b}")
        break

    elif 0 > fa * fb:
        xn = (a + b)/2
        fxn = funcion(xn)
        list_xn.append(xn)
        list_i.append(i)

        if i >= 1:
            X_nuevo = list_xn[i]
            X_anterior = list_xn[i - 1]
            Error = error(X_nuevo, X_anterior)
            list_error.append(Error)
            print(f"Error: {Error}")

        else:
            list_error.append(Error)

        if fa * fxn == 0:
            print(f"La raíz es {xn}")
            break

        elif 0 > fa * fxn:
            b = xn
            fb = fxn

        else:
            a = xn
            fa = fxn

        i += 1
        print(f"En la iteración {i}, xn es {xn}")

    else:
        print(f"La raíz no está en el intervalo [{a}, {b}]")
        break

print(f"La raiz es igual a {xn}")
plt.figure(figsize=(10, 6))

plt.subplot(2, 1, 1)
plt.plot(list_i, list_xn, marker='o', color='b')
plt.title('Convergencia de xn')
plt.xlabel('Iteración')
plt.ylabel('xn')

plt.subplot(2, 1, 2)
plt.plot(list_i, list_error, marker='o', color='r')
plt.title('Error Relativo')
plt.xlabel('Iteración')
plt.ylabel('Error (%)')

plt.tight_layout()
plt.show()
# Out:
# En la iteración 1, xn es -0.5
# Error: 100.0
# En la iteración 2, xn es -0.25
# Error: 33.33333333333333
# En la iteración 3, xn es -0.375
# Error: 14.285714285714285
# En la iteración 4, xn es -0.4375
# Error: 6.666666666666667
# En la iteración 5, xn es -0.46875
# Error: 3.4482758620689653
# En la iteración 6, xn es -0.453125
# Error: 1.7543859649122806
# En la iteración 7, xn es -0.4453125
# Error: 0.8695652173913043
# En la iteración 8, xn es -0.44921875
# Error: 0.43668122270742354
# En la iteración 9, xn es -0.447265625
# Error: 0.2188183807439825
# En la iteración 10, xn es -0.4462890625
# Error: 0.1092896174863388
# En la iteración 11, xn es -0.44677734375
# Error: 0.05461496450027307
# En la iteración 12, xn es -0.447021484375
# Error: 0.027314941272876262
# En la iteración 13, xn es -0.4468994140625
# Error: 0.013659336156262804
# En la iteración 14, xn es -0.44683837890625
# Error: 0.006829201666325207
# En la iteración 15, xn es -0.446868896484375
# La raiz es igual a -0.446868896484375
