# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return x**3 + 2 * x**2 + 10 * x - 20

def m(xi , xf):
    return (f(xf) - f(xi))/(xf - xi)

def error(X_nuevo, X_anterior):
    return np.abs((X_nuevo - X_anterior) / X_nuevo)

a = 10
b = 12
i = 0
iter = 10
Error = 100
list_i = []
list_xn = []
list_error = []
tolerancia = 0.01

while Error >= tolerancia:
    xn = a - f(a)*( 1/ m(a, b))
    list_xn.append(xn)
    if xn < a:
        b = a
        a = xn
    else:
        a = b
        b = xn
    if i >= 1:
        Error = error(list_xn[-1], list_xn[-2])
    list_i.append(i)
    list_error.append(Error)
    print(f"En la iteracion {i} xn es igual a: {xn}")
    print(f"En la iteracion {i} el error es igual a: {Error}")
    print("")
    i += 1


plt.figure(figsize=(12, 8))

plt.subplot(2, 1, 1)
plt.plot(list_i, list_xn, color='b')
plt.title('Convergencia de xn')
plt.xlabel('Iteración')
plt.ylabel('xn')
plt.grid()

plt.subplot(2, 1, 2)
plt.plot(list_i, list_error, color='r')
plt.title('Error Relativo')
plt.xlabel('Iteración')
plt.ylabel('Error (%)')
plt.grid()

plt.tight_layout()
plt.show()
# Out:
# En la iteracion 0 xn es igual a: 6.937799043062201
# En la iteracion 0 el error es igual a: 100
#
# En la iteracion 1 xn es igual a: 5.103039772702391
# En la iteracion 1 el error es igual a: 0.3595424202206807
#
# En la iteracion 2 xn es igual a: 3.5994803618258047
# En la iteracion 2 el error es igual a: 0.4177156866370342
#
# En la iteracion 3 xn es igual a: 2.554977727732486
# En la iteracion 3 el error es igual a: 0.4088108568446517
#
# En la iteracion 4 xn es igual a: 1.8629893006545992
# En la iteracion 4 el error es igual a: 0.3714398289001136
#
# En la iteracion 5 xn es igual a: 1.5046778785435002
# En la iteracion 5 el error es igual a: 0.2381316474579514
#
# En la iteracion 6 xn es igual a: 1.3867050781604338
# En la iteracion 6 el error es igual a: 0.08507418213219933
#
# En la iteracion 7 xn es igual a: 1.369498279218797
# En la iteracion 7 el error es igual a: 0.012564308552072044
#
# En la iteracion 8 xn es igual a: 1.3688116748225816
# En la iteracion 8 el error es igual a: 0.0005016061806343657
